# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **University of Edinburgh**
#
# **School of Mathematics**
#
# **Bayesian Data Analysis, 2020/2021, Semester 2**
#
# **Daniel Paulin & Nicolò Margaritella**
#
# **Assignment 2**

# %% [markdown]
# ## **IMPORTANT INFORMATION ABOUT THE ASSIGNMENT**
#
# In this paragraph, we summarize the essential information about this assignment.
# The format and rules for this assignment are likely different from your other courses, so please pay attention.
#
# **1) Deadline: The deadline for submitting your solutions to this assignment is <u>12th April 2021, 17:00 Edinburgh time</u>.**
#
# **2) Format: You will need to submit your work as 2 components: a report, and the IPython notebook code downloaded from Kaggle (click on File/ Download). There will be two separate submission systems on Learn (Gradescope for the report in PDF format, and a Learn assignment for the code in IPynb format). There are templates in Word and Latex on Learn for the report, please use one of them, and then submit a PDF file. You will be required to tag every sub question on Gradescope.
# A video describing the submission process will be posted on Learn.
# Some key points that are different from other courses:**
#
# **a) Your report needs to contain written explanation for each question that you solve, and some numbers or plots showing your results. Solutions without written explanation that clearly demonstrates that you understand what you are doing will be marked as 0 irrespectively whether the numerics are correct or not.**
#
# **b) Your code has to be possible to run for all questions by the Run All button in Kaggle, and reproduce all of the numerics and plots in your report (up to some small randomness due to stochasticity of Monte Carlo simulations). The parts of the report that contain material that is not reproduced by the code will not be marked (i.e. the score will be 0), and the only feedback in this case will be that the results are not reproducible from the code.**
# ![run_all.jpg](attachment:run_all.jpg)
#
# **c) Multiple Submissions are allowed BEFORE THE DEADLINE are allowed for both the report, and the code. However, multiple submissions are NOT ALLOWED AFTER THE DEADLINE. YOU WILL NOT BE ABLE TO MAKE ANY CHANGES TO YOUR SUBMISSION AFTER THE DEADLINE. Nevertheless, if you did not submit anything before the deadline, then you can still submit your work after the deadline. Late penalties will apply unless you have a valid extension. The timing of the late penalties will be determined by the time you have submitted BOTH the report, and the code (i.e. whichever was submitted later counts).**
#
# We illustrate these rules by some examples:
#
# Alice has spent a lot of time and effort on her assignment for BDA. Unfortunately she introduced a typo in her code in the first question, and it did not run using Run All in Kaggle. - Alice will get 0 for the whole assignment, with the only feedback "Results are not reproducible from the code".
#
# Bob has spent a lot of time and effort on his assignment for BDA. Unfortunately he forgot to submit his code. - Bob will get no personal reminder to submit his code. Bob will get 0 for the whole assignment, with the only feedback "Results are not reproducible from the code, as the code was not submitted."
#
# Charles has spent a lot of time and effort on his assignment for BDA. Unfortunately he though that it is ok to submit his code in R format instead of IPynb. - Charles will get no personal reminder that his code was submitted in the wrong format. Charles will get 0 for the whole assignment, with the only feedback "Results are not reproducible from the code, as the code was submitted in the wrong format."
#
# Denise has spent a lot of time and effort on his assignment for BDA. She has submitted both her code and report in the correct formats. However, she did not include any explanations in the report, simply copied and pasted the numerical results and plots from Kaggle. - Denise will get 0 for the whole assignment, with the only feedback "Explanation is missing."
#
# Eric has spent a lot of time and effort on his assignment for BDA. He has submitted his report in the correct format, but thought that he can include his code as a link in the report, and upload it online (such as Github, or Dropbox). - Eric will get 0 for the whole assignment, with the only feedback "Code was not uploaded in Learn."
#
#
# **3) Group work: This is an INDIVIDUAL ASSIGNMENT, like a 3 week exam for the course. Communication between students about the assignment questions is not permitted. Students who submit work that has not been done individually will be reported for Academic Misconduct, that can lead to serious consequences. Each problem will be marked by a single instructor, so we will be able to spot students who copy.**
#
# **4) Piazza: You are NOT ALLOWED to post questions about Assignment Problems visible to Everyone on Piazza.
# You need to specify the visibility of such questions as Instructors only, by selecting Post to / Individual students/Instructors  and type in Instructors and click on the blue Instructors banner that appears below**
#
# ![piazza_instructors.jpg](attachment:piazza_instructors.jpg)
#
# **Students who post any information related to the solution of assignment problems visible to their classmates will**
#
# **a) have their access to Piazza revoked for the rest of the course without prior warning, and**
#
# **b) reported for Academic Misconduct.**
#
# Only questions regarding clarification of the statement of the problems will be answered by the instructors.
# The instructors will not give you any information related to the solution of the problems,
# such questions will be simply answered as "This is not about the statement of the problem so we cannot answer your question."
#
# The instructors are NOT GOING TO DEBUG YOUR CODE, and you are assessed on your ability to resolve any coding or technical difficulties that you encounter on your own.
#
# **5) Office hours: There will be two office hours per week (Tuesday 12:00-13:00, and Thursdays 9:00-10:00) during the 3 weeks for this assignment. The links are available on Learn / Course Information. We will be happy to discuss the course/workshop materials.
# However, we will only answer questions about the assignment that require clarifying the statement of the problems, and will not give you any information about the solutions. Students who ask for feedback on their assignment solutions during office hours will be removed from the meeting.**
#
# **6) Late submissions and extensions:
# Students who have existing Learning Adjustments in Euclid will be allowed to have the same adjustments applied to this course as well, but they need to apply for this BEFORE THE DEADLINE on the website**
#
# https://www.ed.ac.uk/student-administration/extensions-special-circumstances
#
# **by clicking on "Access your learning adjustment". This will be approved automatically.**
#
# **For students without Learning Adjustments, if there is a justifiable reason (external circumstances) for not being able to submit your assignment in time, then you can apply for an extension BEFORE THE DEADLINE on the website**
#
# https://www.ed.ac.uk/student-administration/extensions-special-circumstances
#
# **by clicking on "Apply for an extension".
# Such extensions are processed entirely by the central ESC team. The course instructors have no role in this decision so you should not write to us about such applications. You can contact our Student Learning Advisor, Maria Tovar Gallardo (<maria.tovar@ed.ac.uk>) in case you need some advice regarding this.**
#
# **Students who submit their work late will have late submission penalties applied by the ESC team automatically (this means that even if you are 1 second late because of your internet connection was slow, the penalties will still apply). The penalties are 5% of the total mark deduced for every day of delay started (i.e. one minute of delay counts for 1 day). The course intructors do not have any role in setting these penalties, we will not be able to change them.**

# %% [markdown]
# # **<p style="text-align: center;"> Problem 1 - Earthquakes in Scotland [45 marks]</p>**
# <img src="attachment:earthquake1.jpg" width=400><p style="text-align: center;">(Image from wtop.com)</p>

# %% [markdown]
# **In this problem, we are going to model the number of Scottish earthquakes `eartScot` with a Local Magnitude scale (ML i.e. the Richter's scale) $\ge 4$ between 1900 and 2020 [1].**
#
# **The available covariates are:**<br>
#
# - `decade` Twelve decades between 1900 and 2020
#
# - `eartrUK` The number of earthquakes in the rest of the UK (from now on we refer to these as "nonScot" events)
#
# - `nrUK>4.5` The number of "nonScot" earthquakes with a magnitude (ML) greater or equal 4.5.
#
# - `dist` Distance (in miles) of the nearest "nonScot" earthquake to the Scottish border.
#
# - `MLrUK` Average magnitude of "nonScot" earthquakes with ML>4
#
# **The goal is to use JAGS to fit several different regression models to this dataset.**
#
# ## <u>IMPORTANT NOTES</u>
# #### ROUND NUMBERS TO NO LESS THAN 3 DECIMAL PLACES (UNLESS DIFFERENTLY SPECIFIED).
# #### ALWAYS CENTER CONTINUOUS COVARIATES (UNLESS DIFFERENTLY SPECIFIED).
# #### ALWAYS REPORT MODEL CHECKS IN NO MORE THAN ONE PAGE AND WITH ONLY PLOTS YOU CONSIDER ESSENTIAL (a description of your findings should often be enough)
#
# **First, we will load JAGS and the dataset from a Sharepoint file and display the first few rows.<br>
# The file (eartScot.RData) is also available on Learn.**
#
#
# [1] data from bgs.ac.uk

# %%
#This code loads a compiled version of JAGS and rjags from a zip file on Onedrive, and loads rjags. It should only take a few seconds.
#IMPORTANT: Go to the Kaggle Settings (right hand side click on K icon) and enable the Internet option in Settings before running this.
system("wget --no-check-certificate -r 'https://uoe-my.sharepoint.com/:u:/g/personal/dpaulin_ed_ac_uk/EX_-yUc-bIZJhLXHcZxpOj8Ba6dwC15X_MjYoox-xM2KlQ?download=1' -O /kaggle/working/kaggle_JAGS.zip")
system("unzip /kaggle/working/kaggle_JAGS.zip")
system("rm /kaggle/working/kaggle_JAGS.zip")
system("cd /kaggle/working/JAGS-4.3.0")
system("make install")
library(rjags,lib.loc="/kaggle/working")
#If it ran correctly, you should see 
#Loading required package: coda
#Linked to JAGS 4.3.0
#Loaded modules: basemod,bugs

#In case you are still experiencing difficulties with this, please use the following code (this compiles and installs JAGS from the source, it takes 6-7 minutes):
#system("wget https://sourceforge.net/projects/mcmc-jags/files/JAGS/4.x/Source/JAGS-4.3.0.tar.gz -P /kaggle/working")
#system("tar xvfz /kaggle/working/JAGS-4.3.0.tar.gz")
#system("cd /kaggle/working/JAGS-4.3.0")
#system("/kaggle/working/JAGS-4.3.0/configure")
#system("make")
#system("make install")
#install.packages("rjags", lib="/kaggle/working")
#library(rjags,lib.loc="/kaggle/working")
#
# Out:
# Error in library(rjags, lib.loc = "/kaggle/working"): no library trees found in 'lib.loc'
# Traceback:
#
# 1. library(rjags, lib.loc = "/kaggle/working")
# 2. stop(txt, domain = NA)

# %%
#This code loads the dataset from a Sharepoint file
system("wget --no-check-certificate -r 'https://uoe-my.sharepoint.com/:u:/g/personal/dpaulin_ed_ac_uk/Ea49MDoxxx1BlA-D4EownqAB78MobxR4Gc90x2VPQ7PbOA?download=1' -O /kaggle/working/earthScot.RData")
#system("wget --no-check-certificate -r 'https://docs.google.com/uc?export=download&id=1PfeMM3Vd13lN6lpVsQCOfxkylt82w-lD' -O /kaggle/working/earthScot.RData")

#We read the data into a dataframe, and display the first few columns
load(file = '/kaggle/working/earthScot.RData')
# the dataframe is called earthQ
head(earthQ)

# %% [markdown]
# **a)<u>[5 marks]</u> Start by exploring the relationship between the response `eartScot` and the covariates. What are the covariates that might be useful to explain the number of eartquakes in Scotland between 1900 and 2020? Use plots and summary statistics to support your comments.**

# %% [markdown]
# **ii a)<u>[5 marks]</u>. Assume that the number of earthquakes in Scotland comes from a Poisson distribution with unknown mean parameter $\mu_i$ which is proportional to the number of nonScot earthquakes, namely,  $\mu_{i}=\lambda∗\text{eartrUK}_{𝑖}$.**
#
# **Carry out a frequentist analysis using the `glm` function, the Poisson family and the default log link function.**
#
# **Report and interpret the mle in the original non-transformed scale.**
#
# **Compute the expected number of earthquakes in Scotland between 1970 and 1980.**
#
# **Plot the observed data by decade with the fitted line added in red; how well does model a1 fit the data?**

# %% [markdown]
# **b)<u>[10 marks]</u> Fit the same Poisson regression model as in a), but now using JAGS. You are given the following three different choices for the prior on lambda:**
#
# $$\lambda\sim\text{Gamma}(0.01,0.01)$$
#
# $$\lambda\sim\text{Gamma}(16,20)$$
#
# $$\lambda\sim\text{Gamma}(a,b);\quad a\sim\text{Lognormal}(ln(\mu_a),\tau_{a}),\sim\text{Lognormal}(ln(\mu_b),\tau_{b}) $$
#
# **Select values for $\mu_a$ and $\mu_b$ such that the expected value of $\lambda$ would be 0.5 and the coefficient of  variation of $\lambda$ would also be 0.5.<br>
# Remember that if $X\sim\text{Gamma}(a,b)$, then $E[X]=a/b,Var[X]=a/b^2$. Also remember that $ CV(X)=\sqrt(Var[X])/E[X]$.**<br>
#
# **Select values for $\tau_{a}$ and $\tau_{b}$ such that the CVs for both are 0.8. Remember that if $Y\sim\text{Lognormal}(ln(\mu),\sigma^{2}) $ then $\sigma^2=\log(CV^{2}+1)$.**
#
# **Conduct prior predictive checks by simulating data under these different priors and use them to**
# - calculate the prior predictive probability for the number of Scottish earthquakes to be greater than 3 and compare it with the data
# - compute the prior predictive probability of observing no earthquake during a decade and comparing it with the data.
#
# **What prior would you choose? Use JAGS to run the model with the best prior for lambda**

# %% [markdown]
# **c)<u>[5 marks]</u> Model c1: Expand model (b) by modelling the rate parameter $\lambda$, as an exponentiated linear function of (centered) `dist`, the distance (in miles) to the nearest nonScot earthquake:**
#
# $$\lambda_{i}=\exp(\beta_{0} + \beta_{1}*(\text{dist}_{i}-mean(\text{dist}))$$
#
# **use Gaussian priors for the betas with mean zero and variance 5. Interpret the results using appropriate transformations for the intercept and the regressor. When commenting on a coefficient, put its numerical meaning into the context of the data.**

# %% [markdown]
# **d)<u>[5 marks]</u> Now consider the inclusion of an extra variance term $\exp(\delta_{i})$ in the definition of $\lambda_{i}$ of model c1. You would use a Gaussian prior for delta with mean zero and standard deviation uniformly distributed between 0 and 5.**
#
# **Write the formula of this new model and its Direct Acyclic Graph (DAG) representation. You should use the file `DAG.tex` available on Learn but a <u>WELL-drawn</u> DAG will also be accepted. Extra care should be taken in representing deterministic vs stochastic nodes and relations as well as in making the DAG as compact and clear as possible (e.g. likelihood, prior and hyperprior levels should be recognizable and if you have $\theta_{j},\,j=1,\dots,N>>0$ you should not draw a node for each $\theta_{j}$)**

# %% [markdown]
# **e)[15 marks] Model the number of earthquakes in Scotland as a function of the number of nonScot earthquakes with magnitude > 4.5 using the same model structure as in (c1). `nrUK>4.5` has some missing data and you will try different approaches to account for it.**
#
# **(5/15 marks) Model (e1): Use conditional mean imputation to impute the missing values in `nrUK>4.5` by using `MLrUK` as  explanatory variable (auxiliary variable) i.e.
# use the `glm` function to fit a Poisson regression model and then impute the missing data using the formula:**
#
# $$\log(\widehat{y_{mis}})=\widehat{\beta_0}+\widehat{\beta_1}x_{mis}$$
#
# **Plug-in your results into `nrUK>4.5` and run the model with JAGS as specified above. Use Gaussian priors for the betas with mean zero and variance 5.**
#
# **(10/15 marks) Model (e2): you are asked to propose a Bayesian solution that includes the imputation  process for the missing values of `nrUK>4.5` within the same model structure of the main model for the number of earthquakes in Scotland.**
#
# **Run the proposed model with JAGS and compare how well the posterior predictive distributions for the number of earthquakes in Scotland in the decade 1900-1910 and 1930-1940 obtained with model (e1) and (e2) fit the original data. Discuss your results.**

# %% [markdown]
# ## **<p style="text-align: center;"> Problem 2 - Wildfires in Algerian forests [55 marks]</p>**
# <img src="attachment:wildfire.jpg" width=400> <p style="text-align: center;">(Image from Wikipedia, Wildfire)</p>

# %% [markdown]
# **In this problem, we will be modelling the probability of wildefire in the forests of two Algerian regions: the Bejaia region, located in the Northest of Algeria and the Sidi Bel-abbes region, in the Northwest.
# The dataset contains daily recordings of metereological variables collected from both regions between June and September 2012 [1].**
#
# - `Region` for Bejaia and Sidi Bel-abbes
# - `month` from June to September 2012
# - `TempCels` Daily temperature in Celsius
# - `RH` Daily relative Humidity (%)
# - `Ws` Daily wind speed (Km/h)
# - `RainYest` Yesterday's precipitations (mm/m^2)
# - `DMC` The Duff Moisture Code is a numeric rating of the average moisture content of loosely compacted organic layers of moderate depth in the forest. It is part of the Canadian Forest Fire Weather Index (FWI).
# - `Fire` Absence/presence (0/1) of a wildfire.
#
# [1]: Adapted from: Faroudja ABID et al. ,Predicting Forest Fire in Algeria using Data Mining Techniques: Case Study of the Decision Tree Algorithmâ, International Conference on Advanced Intelligent Systems for Sustainable Development (AI2SD 2019) , 08 - 11 July , 2019, Marrakech, Morocco.
#
#
# ## <u>IMPORTANT NOTES</u>
# #### ROUND NUMBERS TO NO LESS THAN 3 DECIMAL PLACES (UNLESS DIFFERENTLY SPECIFIED).
# #### ALWAYS CENTER CONTINUOUS COVARIATES (UNLESS DIFFERENTLY SPECIFIED).
# #### ALWAYS REPORT MODEL CHECKS IN NO MORE THAN ONE PAGE AND WITH ONLY PLOTS YOU CONSIDER ESSENTIAL (a description of your findings should often be enough)
#
# **The first step is to load the dataset.**

# %%
#This code loads the dataset from a Sharepoint file
system("wget --no-check-certificate -r 'https://uoe-my.sharepoint.com/:u:/g/personal/dpaulin_ed_ac_uk/EWqDpsmA6VpKs6xC_w6T0NsBDDjl9rXhBEOwkj5AWH221Q?download=1' -O /kaggle/working/AlgForest.csv")
#system("wget --no-check-certificate -r 'https://docs.google.com/uc?export=download&id=1hb89JE7fY8T9wU-KIOfkVqKEF23AtpVe' -O /kaggle/working/AlgForest.csv")

#We read the data into a dataframe, and display the first few columns
AlgForst <- read.csv(file = '/kaggle/working/AlgForest.csv',head=TRUE)
head(AlgForst)

# %% [markdown]
# **a)<u>[5 marks]</u> Explore the relationship between `Fire` and the four meterological variables (temperature, releative humidity, wind speed and rain) in the two Algerian regions.**
#
# **Create a plot with 4 panels; for each panel use the function `boxplot` with the argument `formula` set to produce 4 boxplots, one for each combination of `Fire` and `Region`. What do the plots suggest on the importance of each covariate in explaining the probability of a fire in the two Algerian regions?**

# %% [markdown]
# **b)<u>[5 marks]</u> Using the `glm` function, model the probability of a fire using a Bernoulli logistic model with CENTERED covariates: temperature, relative humidity, wind speed and rain. Report the summary of the model.**
#
# **Interpret the results using appropriate transformations for the intercept and the regressors. When commenting on a coefficient, put its numerical meaning into the context of the data.**
#
# **What is the expected probability of a fire when temperature=35, relative humidity=40, wind speed=18 and rain=1.0?**

# %% [markdown]
# **c)<u>[10 marks]</u> Repeat the Analyses in (b) using a Bayesian Bernoulli logistic model in JAGS. Use Gaussian priors with mean 0 and variance 10 for the intercept and regression coefficients. Use 3 MCMC chains with random starting values drawn from a Gaussian with mean 0 and standard deviation 1. Report and briefly comment the summary of the model.**
#
# **Check convergence with traceplots, Gelman-Rubin-Brooks statistics (and plots); collect a sufficient number of MCMC samples such that the MC error is less than 5% of the posterior standard deviation for all parameters. Report and briefly comment these results in no more than a page.**
#
# **Using only the JAGS output obtained in the previous part of this question (i.e. do NOT modify your JAGS code), compute the posterior expected probability of a fire when Temperature=35, Relative humidity=40, Wind Speed=18 and Rain=1.0. Report posterior mean and 90% credible interval.**

# %% [markdown]
# **d)<u>[20 marks]</u> You are asked to investigate the different probability of wildfire in the two regions, Bejaia and Sidi Bel-abbes, using 3 different Bayesian logistic models.**
#
# - **Model d1: Model the probability of a fire in the two regions using the four metereological covariates with same priors and initial values used in c); however, you will use a different intercept for the two regions. Observations from the Bejaia region should have intercept $\beta_{0}\sim N(0,0.1)$ and you should use a dummy variable (NOT CENTERED) with same Gaussian prior as $\beta_0$ to model the difference in the probability of wildfire in the two regions. Report the model summary.**
#
# - **Model d2: Propose a second model (d2) where the covariate `month` is added to (d1). Add `month` as a categorical variable with 2 levels, July&August vs June&September, the latter being the reference category. Do NOT CENTER this covariate. Allow for a different effect of this covariate in the two Algerian regions. Report the model summary.**
#
# - **Model d3: Propose a third model (d3) where you will add a region and month-specific extra variance term Omega ($\omega[j]$) to model (d1) (NOTE: NOT d2). Note that $j=1,2,\dots,8$ where, e.g., $j=1$ represents June in the Bejaia region and $j=5$ represents June in the Sidi bel-abbes region. Set a Gaussian prior for Omega with zero mean and variance with gamma hyperprior with parameters a=0.01 and b=0.01. Report the model summary.**
#
# #### PERFORM THE FOLLOWING ANALYSES:
#
# **(5/20 marks) model d1:<br>
# Using JAGS, compute the posterior expected probabilities of fire in the Bejaia and Sidi Bel-abbes regions (at average metereological conditions). Use them to plot the two densities in the same graph (use different colours). Briefly comment the plot.**
#
# **(5/20 marks) model d2:<br>
# Using JAGS, compute the posterior expected probabilities of a fire in the Bejaia and Sidi Bel-abbes regions (at average metereological conditions) stratified by the new covariate. Use them to create a plot with two panels (July&August vs June&September) each showing the two posterior densities for the Bejaia and Sidi Bel-abbes regions (use different colours). Briefly comment the plot.**
#
# **(5/20 marks) model d3:<br>
# Using JAGS, compute the posterior expected probability of a fire in the Bejaia and Sidi Bel-abbes regions (at average metereological conditions) stratified by `month`. Use them to create a plot with four panels (one for each month) each showing the relative two posterior densities for the Bejaia and Sidi Bel-abbes regions (use different colours). Comment on the difference between this plot and those of model (d2) and (d3).**
#
# **(5/20 marks) Repeat the analyses of model (d3) with INLA. Report the summary of the models, the posterior distribution of the omega standard deviation (the summary) and compute the posterior probability that relative humidity has a negative influence on the probability of a wildfire (by negative influence, we mean that larger relative humidity results in smaller wildfire probability).**

# %%
#This code unzips an installation of R-INLA from an online source, and loads INLA
#IMPORTANT: Go to the Kaggle Settings (right hand side click on K icon) and enable the Internet option in Settings before running this.
system("wget --no-check-certificate -r 'https://uoe-my.sharepoint.com/:u:/g/personal/dpaulin_ed_ac_uk/EUNBvDg_EJVFqSZJA3Xz7LsB5cVgqYk0HWWnOp74_Dr28A?download=1' -O /kaggle/working/kaggle_INLA.zip")
system("unzip /kaggle/working/kaggle_INLA.zip")
system("rm /kaggle/working/kaggle_INLA.zip")
library(INLA,lib.loc="/kaggle/working")
#If INLA has been successfully loaded, you should see the following:
#This is INLA_20.03.17 built 2021-01-02 20:27:47 UTC.
#See www.r-inla.org/contact-us for how to get help.
#To enable PARDISO sparse library; see inla.pardiso()

#The following code does the full installation. You can try it if the previous code fails, but this takes longer.
#install.packages("INLA",repos=c(getOption("repos"),INLA="https://inla.r-inla-download.org/R/stable"), dep=TRUE,lib="/kaggle/working")
#library(INLA,lib.loc="/kaggle/working")

# %% [markdown]
# **e)<u>[15 marks]</u>**
#
#
# **(5/15 marks) Posterior predictive checks (JAGS): compute random samples of the predictive distributions for replicates of your dataset (same metereological conditions) for models (d2), (d3) and (e1). Model (e1) has the same features of model (d3) -see question d model d3- but with the addition of the `DMC` covariate (CENTERED). Use same prior and initial values as other covariates in model d3.**
#
# **Use these samples to compute the probability of observing a proportion of wildfires for each region and month that is more extreme than those observed in the actual dataset (this is called Bayesian p-value)<br>
# Compute the Deviance Information Criterion (DIC) of the three models. Considering the performance of the three models according to DIC and the posterior predictive checks, which model or models do you consider better for modelling these data?**
#
# **(5/15 marks) Considering that the following metereological conditions (reported below) were registered on 15th October 2012, use model (e1) implemented in JAGS to predict the probability of a fire in one of the two regions during that day.**
#
# - Sidi: Temp=26, RH=20, Ws=13, RainYest=0.0, DMC=12
# - Bejaia: Temp=24, RH=40, Ws=15, RainYest=0.5, DMC=8
#
# **(5/15 marks) Suppose you want to explore the relation between `Fire` and `DMC` by using a simple Bayesian Bernoulli GLM with only two parameters: $\beta_0$ and $\beta_\text{DMC}$ for the CENTERED covariate `DMC`. You have been given prior information to tune your priors for the regression parameters.**<br>
# **An expert affirms that it is unlikely to find a wildfire when DMC<7 while it is very likely to see a wildfire when DMC>20. They also suggest that a 50/50 chance of a fire should be around DMC=10 and DMC=12. Use this information to set the precision of zero-centered Gaussian priors for $\beta_0$ and $\beta_\text{DMC}$. Report your computations.**
